# %% [markdown]
# # W43 Wavelet analysis

# %% [markdown]
# Test of the wavelet analysis technique on the Herschel $l=30^{\circ}$ field.

# %%
import aplpy
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib as mpl
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['ytick.direction'] = 'in'

figfile = '/user/workdir/robitaij/fil2star/Herschel/HOBYS_coldens/dr21_coldens_cf_r500_medsmo3.fits'
fig = aplpy.FITSFigure(figfile)
fig.show_colorscale(cmap='gray',stretch='log',vmid=10**3.0,vmin=5.2e21,vmax=2.0e23)
fig.tick_labels.set_xformat('dd.d')
fig.tick_labels.set_yformat('dd.d')
fig.ticks.set_minor_frequency(4)
fig.ticks.set_xspacing(0.5)  # degrees
fig.ticks.set_yspacing(0.5)  # degrees
fig.add_colorbar()
fig.colorbar.set_axis_label_text(r'cm$^{-2}$')
