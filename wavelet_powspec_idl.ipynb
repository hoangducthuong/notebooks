# %% [markdown]
# # Wavelet Power Spectrum

# %%
print, 'Hello'
# Out:
# Hello

# %%
fbm = fbm2d(-3.1,256,256,seed)

# %%
;;This enables inline plotting
!inline=1

# %%
powspec_k_nosquare,fbm,1,tab_k,spec_k

;mamdct,75
window,xsize=800,ysize=500
plot,tab_k,spec_k,/xlog,/ylog,xtitle='Wavenumber k',ytitle='P[k]'

# %%
fbm = fbm2d(-3.1,256,256,seed)
mamdct,75
window,xsize=800,ysize=800
imaffi,fbm,/bar

# %% [markdown]
# Show histogram

# %%
histo = histogram(fbm,nbins=50,locations=x)

window,/free
plot,x,histo,psym=10,xtitle='Values',ytitle='Counts'
